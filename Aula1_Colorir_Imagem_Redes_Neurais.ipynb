# %% [markdown]
# <a href="https://colab.research.google.com/github/JOILSONSAMPAIO/DataScience/blob/main/Aula1_Colorir_Imagem_Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget = https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-12-08 22:28:02--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2020-12-08 22:28:02--  https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-08 22:28:02 (43.2 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]
#
# FINISHED --2020-12-08 22:28:02--
# Total wall clock time: 0.07s
# Downloaded: 1 files, 2.6K in 0s (43.2 MB/s)

# %%
from deoldify_wrapper import DeOldify
# Out:
#   Importing Libraries
# No module named 'deoldify'
# DeOldify not found, installing..
#   Cloning DeOldify Repository...
#   Opening DeOldify Folder
#   Importing Libraries
# /content/deoldify_wrapper.py:36: UserWarning: WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings
#   warnings.warn('WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings')
#   Installing Colab requirements...
#   Importing DeOldify Visualize module and FastAI
# ...

# %%
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...
# Done!

# %%
# !wget https://i0.wp.com/metro.co.uk/wp-content/uploads/2019/04/Royal-BW-e547.jpg?quality=90&strip=all&zoom=1&resize=768%2C524&ssl=1
# Out:
# --2020-12-08 22:31:20--  https://i0.wp.com/metro.co.uk/wp-content/uploads/2019/04/Royal-BW-e547.jpg?quality=90
# Resolving i0.wp.com (i0.wp.com)... 192.0.77.2
# Connecting to i0.wp.com (i0.wp.com)|192.0.77.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388575 (379K) [image/jpeg]
# Saving to: ‘Royal-BW-e547.jpg?quality=90’
#
# Royal-BW-e547.jpg?q 100%[===================>] 379.47K  --.-KB/s    in 0.02s
#
# 2020-12-08 22:31:20 (18.8 MB/s) - ‘Royal-BW-e547.jpg?quality=90’ saved [388575/388575]

# %%
deo.colorize('https://i0.wp.com/metro.co.uk/wp-content/uploads/2019/04/Royal-BW-e547.jpg',render_factor = 15)
